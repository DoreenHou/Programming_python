# %%
#my first code
a = "HOU"
b = 47

# %%
print(a)
print(b)
# Out:
# HOU
# 47

# %%
'''
The programme
with loop
'''
#this is loop
for i in a:
    print(i)
# Out:
# H
# O
# U

# %%
a[0]
# Out:
# 'H'

# %%
c = 30

# %%
i = 1
for i in range(6):
    print(i+1)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
def my_function(frame):
    print(frame + " Refsnes")

my_function("Email")
my_function("Tobias")
my_function("Linus")
# Out:
# Email Refsnes
# Tobias Refsnes
# Linus Refsnes

# %%
def atil(frame):
    print(frame + " Refsnes")

my_function("Email")
my_function("Tobias")
my_function("Linus")
# Out:
# Email Refsnes
# Tobias Refsnes
# Linus Refsnes

# %%
def atil
